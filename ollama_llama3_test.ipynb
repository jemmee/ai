# %%
# !ollama list
# Out:
# ]11;?\NAME                 ID              SIZE      MODIFIED
# llama3.2:1b          baf6a787fdff    1.3 GB    About a minute ago
# glm4:latest          5b699761eca5    5.5 GB    21 minutes ago
# all-minilm:latest    1b226e2802db    45 MB     40 hours ago
# gemma2:2b            8ccf136fdd52    1.6 GB    7 days ago

# %%
import ollama

def local_chat_loop():
    model_name = "llama3.2:1b"
    
    # Initialize the conversational history with a system behavior rule
    messages = [
        {"role": "system", "content": "You are a concise engineering assistant. Provide technical, punchy answers."}
    ]
    
    print(f"--- Local Chat Initialized using {model_name} (Type 'quit' to exit) ---")
    
    while True:
        user_input = input("\nYou: ")
        if user_input.lower() == "quit":
            break
            
        # Append the new user prompt to the history stack
        messages.append({"role": "user", "content": user_input})
        
        print("AI: ", end="", flush=True)
        
        # Stream the response chunk by chunk to prevent UI lag
        stream = ollama.chat(model=model_name, messages=messages, stream=True)
        
        full_response = ""
        for chunk in stream:
            content = chunk.message.content
            print(content, end="", flush=True)
            full_response += content
            
        # Commit the model's response to memory so follow-up context works
        messages.append({"role": "assistant", "content": full_response})
        print()

if __name__ == "__main__":
    local_chat_loop()
# Out:
# --- Local Chat Initialized using llama3.2:1b (Type 'quit' to exit) ---
# You:  Why is the sky blue? Answer in exactly 1 sentence.
# AI: The sky appears blue because of a phenomenon called Rayleigh scattering, where shorter wavelengths of light (like blue and violet) scatter more easily than longer wavelengths (like red and orange), resulting in the blue color we see.
